# %% [markdown]
# # Import Libraries

# %%
#Import Libraries For Work     
import os
import tweepy as tw
import pandas as pd
import re
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
consumer_key= 'yYTMA0FrdKEy895eR4xKoL7wq'
consumer_secret= 'j6exDlTTAQSetgESjRVHBu0pAzTI6cN5hiM6uk3lv4LPADqjlg'
access_token= '1471429945197010952-lAQpK32K7vPbGDdvSW81zR1UMUCJvk'
access_token_secret= 'AFaFOKCgQNEpxq7HRGlbrV8RU3gh7HSFGNWMyABMiN4RQ'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)http://localhost:8888/notebooks/Untitled2.ipynb#
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term and the date_since date as variables
search_words = "#bitcoin"
texting = []

# %% [markdown]
# # Collect Twitter

# %%
# Collect tweet
Tweets_d = []
tweets = tw.Cursor(api.search_tweets,
              q=search_words,
              lang="en").items(500)

# %%
for tweet in tweets:
    texting.append(tweet.text)

# %% [markdown]
# # Clean and visual

# %%
for i in texting:
    new_twee = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", i).split())
    Tweets_d.append(new_twee)

# %%
# importing all necessary modules
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in Tweets_d:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
